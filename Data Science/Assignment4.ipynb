# %%
import pandas as pd
import numpy as np
import seaborn as sns
from google.colab import drive
drive.mount('/content/gdrive')
import requests
from lxml import html as html

#Q1
string = open('/content/gdrive/My Drive/files for CS 441/assign4_use.xml', 'r').read()
tree = html.document_fromstring(string)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Q2
html.tostring(tree).splitlines()
# Out:
# [b'<html><body><p>xml version ="1.0" standalone = "yes" ?&gt;',
#  b'<university>',
#  b'    <student id="1001" course="CS 101">',
#  b'        <name>Bob Ross</name>',
#  b'        <address>22732 Sunset Blvd. Hollywood</address>',
#  b'    </student>',
#  b'    <student id="1002" course="CS 488">',
#  b'        <name>Ross Rob</name>',
#  b'        <address>47588 Highwayne Jackwood</address>',
#  b'    </student>',
#  b'    <course id="CS 488" teacher="2001" students="1001">',
#  b'        <name>CS 488</name>',
#  b'        <student_id>"1001"</student_id>',
#  b'    </course>',
#  b'    <course id="CS 101" teacher="2002" students="1002">',
#  b'        <name>CS 101</name>',
#  b'        <student_id>"1002"</student_id>',
#  b'    </course>',
#  b'    <course id="CSC366" teacher="2002">',
#  b'        <name>CSC366</name>',
#  b'        <student_id>"1002"</student_id>',
#  b'    </course>',
#  b'    <teacher employeeid="2001" course="CS 488">',
#  b'        <name>CS 488</name>',
# ...

# %%
#Q3
print('Course: ' + tree.xpath('//*[contains(@id, "CSC366")]/*')[0].text_content())
print('Student_ID: ' + tree.xpath('//*[contains(@id, "CSC366")]/*')[1].text_content())
# Out:
# Course: CSC366
# Student_ID: "1002"

# %%
#Q4
import json
with open("/content/gdrive/My Drive/files for CS 441/assign4.json", "r") as read_file:
  data = json.load(read_file)
data
# Out:
# {'Student': [{'name': 'Bob Ross',
#    'ID': 1001,
#    'course': 'CS 101',
#    'address': '2732 Sunset Blvd. Hollywood'},
#   {'name': 'Ross Rob',
#    'ID': 1002,
#    'course': 'CSC366',
#    'address': '47588 Highwayne Jackwood'}],
#  'Course': [{'ID': 'CS 101', 'Teacher': 2002, 'Student': 1001},
#   {'ID': 'CSC366', 'Teacher': 2001, 'Student': 1002}],
#  'Teacher': [{'ID': 2001, 'course': 'CSC366'},
#   {'ID': 2002, 'course': 'CS 101'}]}

# %%
#Q5
data['Course']['ID' == 'CSC366']['Student']
# Out:
# 1001
